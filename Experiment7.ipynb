# %%
#colors in set1 but not in set2.
set1=set(input("Enter colors in set1:").split())
set2=set(input("Enter colors in set2:").split())
print("Set1=",set1)
print("Set2=",set2)
print("The colors in set1 but not in set2:",set1.difference(set2))
# Out:
# Enter colors in set1: Green Yellow Orange Blue
# Enter colors in set2: Orange Red Blue Purple
# Set1= {'Blue', 'Yellow', 'Green', 'Orange'}
# Set2= {'Blue', 'Red', 'Orange', 'Purple'}
# The colors in set1 but not in set2: {'Yellow', 'Green'}

# %%
#Display all the colors in two sets.
s1=set(input("Enter colors in set1:").split())
s2=set(input("Enter colors in set2:").split())
print("Set1=",s1)
print("Set2=",s2)
print("The colors in both sets are:",s1.union(s2))
# Out:
# Enter colors in set1: Green Yellow Orange Blue
# Enter colors in set2: Orange Red Blue Purple
# Set1= {'Blue', 'Yellow', 'Green', 'Orange'}
# Set2= {'Blue', 'Red', 'Orange', 'Purple'}
# The colors in both sets are: {'Yellow', 'Green', 'Orange', 'Blue', 'Red', 'Purple'}
