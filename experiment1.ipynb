# %%
#write a python program that accept an integer(n) AND COMPUTE THE VALUE OF n+nn+nnn
n=input("Enetr the number:")
n1=int(n)
n2=int(n*2)
n3=int(n*3)
result=n1+n2+n3
print("The result is",n1,"+",n2,"+",n3,"=",result)
# Out:
# Enetr the number: 5
# the result is 5 + 55 + 555 = 615

# %%
#input the radius of acircle and compute the area(import math)
import math
radius=float(input("Enter the radius:"))
area=math.pi*radius*radius
print(f"Area of the circle is:{area:.2f}")
# Out:
# Enter the radius: 3
# Area of the circle is:28.27

# %%
#write a programto find the biggest of three numbers (use max())
a=int(input("Enter the a:"))
b=int(input("enter the b:"))
c=int(input("Enter the c:"))
biggest=max(a,b,c)
print("The biggest number is:",biggest)
# Out:
# Enter the a: 2
# enter the b: 8
# Enter the c: -3
# The biggest number is: 8
