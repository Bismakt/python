# %%
#sort dictionary ascending or descending order
roll=input("Enter Roll(Space separated): ").split()
name=input("Enter Name(Space separated): ").split()
mydict=dict(zip(roll,name))
print("Original dictionary is:",mydict)
print("Ascending order:",dict(sorted(mydict.items())))
print("Descending order:",dict(sorted(mydict.items(),reverse=True)))
# Out:
# Enter Roll(Space separated):  1 2 3 4 5 6
# Enter Name(Space separated):  bisma devananda rasha anamika sumaida linsha
# Original dictionary is: {'1': 'bisma', '2': 'devananda', '3': 'rasha', '4': 'anamika', '5': 'sumaida', '6': 'linsha'}
# Ascending order: {'1': 'bisma', '2': 'devananda', '3': 'rasha', '4': 'anamika', '5': 'sumaida', '6': 'linsha'}
# Descending order: {'6': 'linsha', '5': 'sumaida', '4': 'anamika', '3': 'rasha', '2': 'devananda', '1': 'bisma'}

# %%
dic1=dict(zip(input("Enter 3 roll number:").split(),input("Enter 3  names:").split()))
dic2=dict(zip(input("Enter 2 roll number:").split(),input("Enter 2  names:").split()))
print("dictionary1=",dic1)
print("dictionary2=",dic2)
dic1.update(dic2)
print("Merged dictionary:",dic1)
# Out:
# Enter 3 roll number:  1 2 3
# Enter 3  names: bisma devananda rasha
# Enter 2 roll number:  4 5
# Enter 2  names: anamika sumaida
# dictionary1= {'1': 'bisma', '2': 'devananda', '3': 'rasha'}
# dictionary2= {'4': 'anamika', '5': 'sumaida'}
# Merged dictionary: {'1': 'bisma', '2': 'devananda', '3': 'rasha', '4': 'anamika', '5': 'sumaida'}
